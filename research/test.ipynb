# %%
import sys
sys.path.append('..')

from steganogan_nc_custom.models import SteganoGAN

# %%
# Load the model
steganogan = SteganoGAN.load(path='models/custom_nc/1761963794/weights.steg', cuda=False)

# %%
# Encode a message in input.png
steganogan.encode('input.png', 'output.png', 'This is a super secret message!')

# %%
# Decode the message from output.png
steganogan.decode('output.png')
# Out:
# 'This is a super secret message!'
