# %%
import sys
sys.path.append('..')

from steganogan_nc_aes.models import SteganoGAN

# %%
# Load the model
steganogan = SteganoGAN.load(path='/Users/dmitryhoma/Projects/phd_dissertation/state_3/NNSteganoGAN/research/models/no_critic_with_aes/1761964732/weights.steg', cuda=False)

# %%
# Encode a message in input.png
steganogan.encode('input.png', 'output.png', 'This is a super secret message!', 'password123')

# %%
# Decode the message from output.png
steganogan.decode('output.png', 'password123')
# Out:
# ('This is a super secret message!', 'password123')

# %%
steganogan.decode('output.png', 'wrong password')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 steganogan.decode('output.png', 'wrong password')
#
# File ~/Projects/phd_dissertation/state_3/NNSteganoGAN/research/../steganogan_nc_aes/models.py:392, in SteganoGAN.decode(self, image, password)
#     389 decoded_password_candidate = most_common_candidate_from(decoded_password)
#     391 if not decoded_password_candidate == password:
# --> 392     raise ValueError('Incorrect password!')
#     394 # Attempt AES decryption of the decoded data using the provided password
#     395 aes = AESCipher(password)
#
# ValueError: Incorrect password!
